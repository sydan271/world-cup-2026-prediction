# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# load the results

# %%
results_df = pd.read_csv('tournament_results.csv')
